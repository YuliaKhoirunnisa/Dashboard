# %% [markdown]
# # Proyek Analisis Data: [Project_Analisis_data]
# - **Nama:** [Yulia Khoirunnisa]
# - **Email:** [yuliakhoirunnisa26@gmail.com]
# - **ID Dicoding:** [MC224D5X0960]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana Pengaruh Musim dan Cuaca Terhadap Jumlah Penyewaan Sepeda?
# - Pertanyaan 2: Pada Jam Berapa Peminat Penyewaan Sepeda Tertinggi dan Terendah?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
pd.read_csv('day.csv')
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
pd.read_csv('hour.csv')
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Menampilkan 5 baris pertama dari data frame day_df
# - Menampilkan 5 baris pertama dari data frame hour_df

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Pada data day_df tidak ada missing value akan tetapi terdapat kesalahan tipe data untuk kolom dteday koloh tersebut seharusnya sebagai tipe data datetime bukan object
# - Tidak ada duplikat data pada data day_df
# - Pada data hour_df tidak ada missing value akan tetapi terdapat kesalahan tipe data untuk kolom dteday koloh tersebut seharusnya sebagai tipe data datetime bukan object
# - Tidak ada duplikat data pada data hour_df

# %% [markdown]
# ### Cleaning Data

# %%
datetime_columns = ["dteday"]
 
for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
# Dictionary untuk mengganti angka dengan nama hari
weekday_map = {
    0: "Senin", 1: "Selasa", 2: "Rabu", 3: "Kamis",
    4: "Jumat", 5: "Sabtu", 6: "Minggu"
}

# Mengganti angka di weekday dengan nama hari
day_df["weekday"] = day_df["weekday"].map(weekday_map)

# Cek hasil perubahan
print(day_df[["dteday", "weekday"]].head())
# Out:
#       dteday weekday
# 0 2011-01-01  Minggu
# 1 2011-01-02   Senin
# 2 2011-01-03  Selasa
# 3 2011-01-04    Rabu
# 4 2011-01-05   Kamis

# %%
day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0  Minggu           0
# 1        2 2011-01-02       1   0     1        0   Senin           0
# 2        3 2011-01-03       1   0     1        0  Selasa           1
# 3        4 2011-01-04       1   0     1        0    Rabu           1
# 4        5 2011-01-05       1   0     1        0   Kamis           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
datetime_columns = ["dteday"]
 
for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
# Dictionary untuk mengganti angka dengan nama hari
weekday_map = {
    0: "Senin", 1: "Selasa", 2: "Rabu", 3: "Kamis",
    4: "Jumat", 5: "Sabtu", 6: "Minggu"
}

# Mengganti angka di weekday dengan nama hari
hour_df["weekday"] = hour_df["weekday"].map(weekday_map)

# Cek hasil perubahan
print(hour_df[["dteday", "weekday"]].head())
# Out:
#       dteday weekday
# 0 2011-01-01  Minggu
# 1 2011-01-01  Minggu
# 2 2011-01-01  Minggu
# 3 2011-01-01  Minggu
# 4 2011-01-01  Minggu

# %%
hour_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0  Minggu           0
# 1        2 2011-01-01       1   0     1   1        0  Minggu           0
# 2        3 2011-01-01       1   0     1   2        0  Minggu           0
# 3        4 2011-01-01       1   0     1   3        0  Minggu           0
# 4        5 2011-01-01       1   0     1   4        0  Minggu           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Cleaning Data selesai

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
# Menghitung total penyewaan sepeda per hari
bike_rentals_per_day = day_df.groupby("weekday")["cnt"].sum()

print(bike_rentals_per_day)
# Out:
# weekday
# Jumat     485395
# Kamis     473048
# Minggu    477807
# Rabu      469109
# Sabtu     487790
# Selasa    455503
# Senin     444027
# Name: cnt, dtype: int64

# %%
max_day = bike_rentals_per_day.idxmax()  # Hari dengan penyewaan tertinggi
max_rentals = bike_rentals_per_day.max() # Jumlah penyewaan tertinggi

print(f"Penyewaan tertinggi terjadi pada hari {max_day} dengan total {max_rentals} penyewaan.")
# Out:
# Penyewaan tertinggi terjadi pada hari Sabtu dengan total 487790 penyewaan.

# %%
min_day = bike_rentals_per_day.idxmin()  # Hari dengan penyewaan terendah
min_rentals = bike_rentals_per_day.min()  # Jumlah penyewaan terendah

print(f"Penyewaan terendah terjadi pada hari {min_day} dengan total {min_rentals} penyewaan.")
# Out:
# Penyewaan terendah terjadi pada hari Senin dengan total 444027 penyewaan.

# %%
# Load dataset per jam (gantilah "hour.csv" jika datasetnya berbeda)
hour_df = pd.read_csv("hour.csv")

# Menghitung total penyewaan sepeda per jam
bike_rentals_per_hour = hour_df.groupby("hr")["cnt"].sum()

# Menampilkan hasil
print(bike_rentals_per_hour)
# Out:
# hr
# 0      39130
# 1      24164
# 2      16352
# 3       8174
# 4       4428
# 5      14261
# 6      55132
# 7     154171
# 8     261001
# 9     159438
# 10    126257
# 11    151320
# 12    184414
# 13    184919
# 14    175652
# 15    183149
# 16    227748
# 17    336860
# 18    309772
# 19    226789
# 20    164550
# 21    125445
# 22     95612
# 23     63941
# Name: cnt, dtype: int64

# %%
bike_rentals_per_hour = hour_df.groupby("hr")["cnt"].sum()

max_hour = bike_rentals_per_hour.idxmax()  # Jam dengan penyewaan tertinggi
min_hour = bike_rentals_per_hour.idxmin()  # Jam dengan penyewaan terendah
max_rentals = bike_rentals_per_hour.max()  # Jumlah penyewaan tertinggi
min_rentals = bike_rentals_per_hour.min()  # Jumlah penyewaan terendah

print(f"Penyewaan tertinggi terjadi pada pukul {max_hour}:00 dengan total {max_rentals} penyewaan.")
print(f"Penyewaan terendah terjadi pada pukul {min_hour}:00 dengan total {min_rentals} penyewaan.")
# Out:
# Penyewaan tertinggi terjadi pada pukul 17:00 dengan total 336860 penyewaan.
# Penyewaan terendah terjadi pada pukul 4:00 dengan total 4428 penyewaan.

# %%
# Menghitung total penyewaan sepeda per jam
bike_rentals_per_hour = hour_df.groupby("hr")["cnt"].sum().reset_index()

# Menentukan jam dengan penyewaan tertinggi dan terendah
max_rental = bike_rentals_per_hour.loc[bike_rentals_per_hour["cnt"].idxmax()]
min_rental = bike_rentals_per_hour.loc[bike_rentals_per_hour["cnt"].idxmin()]

# Membuat DataFrame hasil
result_df = pd.DataFrame({
    "Kategori": ["Tertinggi", "Terendah"],
    "Jam": [max_rental["hr"], min_rental["hr"]],
    "Total Penyewaan": [max_rental["cnt"], min_rental["cnt"]]
})

print(result_df)
# Out:
#     Kategori  Jam  Total Penyewaan
# 0  Tertinggi   17           336860
# 1   Terendah    4             4428

# %% [markdown]
# **Insight:**
# - Penyewaan tertinggi terjadi pada pukul 17:00 dengan total 336860 penyewaan.
# - Penyewaan terendah terjadi pada pukul 4:00 dengan total 4428 penyewaan.
# - Penyewaan tertinggi terjadi pada pukul 17:00 saat musim 3 dan cuaca 1 dengan total 85206 penyewaan.
# - Penyewaan terendah terjadi pada pukul 1:00 saat musim 1 dan cuaca 4 dengan total 23 penyewaan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana Pengaruh Musim dan Cuaca Terhadap Jumlah Penyewaan Sepeda?

# %%
# Menghitung total penyewaan sepeda berdasarkan musim dan cuaca
bike_rentals_season_weather = hour_df.groupby(["season", "weathersit"])["cnt"].sum().reset_index()

# Mengubah kode musim menjadi label
season_labels = {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"}
weather_labels = {1: "Clear", 2: "Cloudy", 3: "Rain/Snow"}

bike_rentals_season_weather["season"] = bike_rentals_season_weather["season"].map(season_labels)
bike_rentals_season_weather["weathersit"] = bike_rentals_season_weather["weathersit"].map(weather_labels)

# Membuat plot dengan Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=bike_rentals_season_weather, x="season", y="cnt", hue="weathersit", palette="coolwarm")

# Menambahkan judul dan label
plt.title("Pengaruh Musim dan Cuaca terhadap Jumlah Penyewaan Sepeda", fontsize=14)
plt.xlabel("Musim", fontsize=12)
plt.ylabel("Total Penyewaan", fontsize=12)
plt.legend(title="Kondisi Cuaca")

plt.show()

# %% [markdown]
# ### Pertanyaan 2: Pada Jam Berapa Peminat Penyewaan Sepeda Tertinggi dan Terendah?

# %%
df = pd.read_csv("hour.csv")

# Mengelompokkan data berdasarkan jam dan menghitung total penyewaan sepeda
bike_rentals_per_hour = df.groupby("hr")["cnt"].sum()

# Mencari jam dengan penyewaan tertinggi dan terendah
max_hour = bike_rentals_per_hour.idxmax()
max_rentals = bike_rentals_per_hour.max()
min_hour = bike_rentals_per_hour.idxmin()
min_rentals = bike_rentals_per_hour.min()

# Membuat figure untuk visualisasi
plt.figure(figsize=(12, 6))

# Line plot jumlah penyewaan per jam
sns.lineplot(x=bike_rentals_per_hour.index, y=bike_rentals_per_hour.values, marker="o", label="Penyewaan Sepeda")

# Menandai jam dengan penyewaan tertinggi dan terendah
plt.scatter(max_hour, max_rentals, color='red', s=100, label=f"Max: {max_hour}:00 ({max_rentals})")
plt.scatter(min_hour, min_rentals, color='blue', s=100, label=f"Min: {min_hour}:00 ({min_rentals})")

# Menambahkan keterangan
plt.xlabel("Jam")
plt.ylabel("Jumlah Penyewaan")
plt.title("Jumlah Penyewaan Sepeda per Jam")
plt.xticks(range(0, 24))  # Menampilkan semua jam dari 0 sampai 23
plt.legend()
plt.grid(True)

# Menampilkan grafik
plt.show()

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
import pandas as pd

df_day = pd.read_csv('day.csv')
df_hour = pd.read_csv('hour.csv')

# Gabungkan dataset (sesuaikan berdasarkan kebutuhan)
all_df = pd.concat([df_day, df_hour], ignore_index=True)

# Simpan ke CSV
all_df.to_csv("all_data.csv", index=False)
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[32], line 1
# ----> 1 all_df.to_csv("all_data.csv", index=False)
#
# NameError: name 'all_df' is not defined

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Pertanyaan 1: Pengaruh Musim dan Cuaca terhadap Jumlah Penyewaan Sepeda**
# - **Jumlah penyewaan tertinggi** terjadi pada musim **gugur (fall) dengan kondisi cuaca cerah**, mencapai sekitar **800.000 penyewaan**. Hal ini kemungkinan besar karena suhu yang lebih nyaman untuk bersepeda serta adanya peningkatan aktivitas luar ruangan sebelum musim dingin tiba.
# - **Jumlah penyewaan terendah** terjadi pada musim **semi (spring) dengan kondisi hujan/salju**, hanya sekitar **30.000 penyewaan**. Musim semi seringkali memiliki cuaca yang lebih tidak stabil, termasuk hujan, yang dapat mengurangi minat masyarakat dalam menyewa sepeda.
#
# **Rekomendasi:**
# 1. **Peningkatan layanan selama musim gugur** – Operator penyewaan sepeda dapat menambahkan lebih banyak sepeda dan meningkatkan fasilitas di musim gugur karena permintaan tinggi.
# 2. **Strategi promosi di musim semi dan musim dingin** – Menawarkan diskon atau promo khusus untuk menarik lebih banyak penyewa di musim dengan permintaan rendah.
# 3. **Penyediaan fasilitas pelindung cuaca** – Menyediakan stasiun parkir yang lebih terlindungi dan sepeda dengan aksesori tahan cuaca agar lebih nyaman digunakan dalam kondisi mendung atau hujan.
#
# **Pertanyaan 2: Jam Peminat Penyewaan Sepeda Tertinggi dan Terendah**
# - **Jumlah penyewaan tertinggi** terjadi pada pukul **17:00 dengan 336.860 penyewaan**. Ini menunjukkan bahwa banyak orang menggunakan sepeda sebagai sarana transportasi setelah jam kerja atau untuk beraktivitas sore hari.
# - **Jumlah penyewaan terendah** terjadi pada pukul **04:00 dengan hanya 4.428 penyewaan**, yang masuk akal karena waktu ini merupakan dini hari ketika sebagian besar orang masih beristirahat.
#
# **Rekomendasi:**
# 1. **Penyesuaian jumlah sepeda berdasarkan jam sibuk** – Menyediakan lebih banyak sepeda menjelang sore hari (16:00-18:00) untuk mengakomodasi lonjakan permintaan.
# 2. **Peningkatan pencahayaan dan keamanan malam** – Meningkatkan pencahayaan di area parkir sepeda untuk mendorong penggunaan di jam malam yang lebih sepi.
# 3. **Promo penyewaan malam hari** – Menawarkan diskon atau insentif bagi pengguna yang menyewa sepeda pada jam-jam sepi untuk meratakan distribusi penggunaan sepeda sepanjang hari.
